# %%
# import required modules
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# Setting the options to display maximum rows and columns in the output
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ##### Step 1 - load the dataset and understand it

# %%
# load the excel file and store it in a variable called df
df = pd.read_excel(r"C:\Users\aswin\OneDrive\Documents\Crime_Data.xlsx")

# %%
df.shape
# Out:
# (549999, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  datetime64[ns]
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
#  14  FBI Code              549999 non-null  object
#  15  X Coordinate          543087 non-null  float64
#  16  Y Coordinate          543087 non-null  float64
#  17  Year                  549999 non-null  int64
#  18  Updated On            549999 non-null  datetime64[ns]
#  19  Latitude              543087 non-null  float64
#  20  Longitude             543087 non-null  float64
#  21  Location              543087 non-null  object
# dtypes: bool(2), datetime64[ns](2), float64(6), int64(4), object(8)
# memory usage: 85.0+ MB

# %%
df.head(3)
# Out:
#         ID Case Number                Date                  Block IUCR  \
# 0  5741943    HN549294 2007-08-25 09:22:18     074XX N ROGERS AVE  560
# 1    25953    JE240540 2021-05-24 15:06:00    020XX N LARAMIE AVE  110
# 2    26038    JE279849 2021-06-26 09:24:00  062XX N MC CORMICK RD  110
#
#   Primary Type          Description Location Description  Arrest  Domestic  \
# 0      ASSAULT               SIMPLE                OTHER   False     False
# 1     HOMICIDE  FIRST DEGREE MURDER               STREET    True     False
# 2     HOMICIDE  FIRST DEGREE MURDER          PARKING LOT    True     False
#
#    Beat  District  Ward  Community Area FBI Code  X Coordinate  Y Coordinate  \
# 0  2422        24  49.0             1.0      08A           NaN           NaN
# 1  2515        25  36.0            19.0      01A     1141387.0     1913179.0
# 2  1711        17  50.0            13.0      01A     1152781.0     1941458.0
#
#    Year          Updated On   Latitude  Longitude  \
# 0  2007 2015-08-17 15:03:40        NaN        NaN
# 1  2021 2023-11-18 15:39:49  41.917838 -87.755969
# 2  2021 2023-11-18 15:39:49  41.995219 -87.713355
#
#                         Location
# 0                            NaN
# 1  (41.917838056, -87.755968972)
# 2  (41.995219444, -87.713354912)

# %% [markdown]
# ##### Step 2 -- Find misspelled words in the dataset and replace it with meaningful word

# %%
# category columns in the dataset
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'FBI Code', 'Location'],
#       dtype='object')

# %%
# Unique values in all category columns
for i in cat_cols:
    print(f'unique values in {i} column')
    print(df[i].unique())
    print('-'*70)
# Out:
# unique values in Case Number column
# ['HN549294' 'JE240540' 'JE279849' ... 'G583569' 'G610965' 'G627247']
# ----------------------------------------------------------------------
# unique values in Block column
# ['074XX N ROGERS AVE' '020XX N LARAMIE AVE' '062XX N MC CORMICK RD' ...
#  '042XX W DRUMMOND PL' '030XX E 106 ST' '040XX W 70 ST']
# ----------------------------------------------------------------------
# unique values in IUCR column
# [560 110 620 454 820 1320 1153 281 1310 810 1120 890 1110 1790 910 1156
#  '031A' 266 325 1753 1565 2826 1752 1544 1562 1477 1751 486 1754 583 265
#  860 1350 1220 1330 920 497 5002 '502P' 520 '502R' '041A' 320 1513 1152
#  420 1020 1340 460 2820 630 610 4387 '051A' 2027 1365 930 498 1710 580
#  4230 330 '031B' 313 1563 1130 530 1360 1478 1780 '143A' 1121 430 1345
#  1210 2024 1150 3710 326 1581 1206 2850 1195 479 2890 917 1750 2029 '033A'
#  484 870 '141B' 462 2021 5000 331 650 1151 5011 1200 2825 1812 1154 927
#  2092 1242 2022 2028 584 1155 '141C' 1822 495 1140 263 1582 850 1122 1585
#  1570 496 5111 2860 2093 558 488 '051B' 3760 5110 440 1090 1305 4310 334
#  470 880 4389 485 1811 '501A' 2830 340 937 550 5001 4210 3730 1541 2251
#  312 2170 554 475 2210 3960 545 2025 2026 1792 1185 '143C' '141A' 552 1241
#  1720 915 1480 461 4650 1055 1025 4386 1661 3731 291 482 1261 483 2014 557
#  2250 1506 453 918 5130 1240 1755 2031 3750 3200 261 1540 4651 337 3970
#  '142A' 5007 2017 1821 553 555 1170 935 2023 4255 2091 2090 1507 1460 1205
#  865 275 2851 5112 '502T' '143B' 2032 264 1335 2870 1479 581 '033B' 2896
#  4625 2900 1537 4388 4860 2020 2050 938 '041B' 4652 5004 1580 1135 1375
#  450 2013 925 '501H' 271 '500N' 3100 1535 2012 142 1050 4240 2011 2018
#  '500E' 928 5003 3300 3800 1576 2220 556 5132 2010 5131 4220 1549 273 2015
#  3910 1900 5009 2160 1481 1574 842 1245 1536 551 2840 1030 895 487 5121
#  1590 2895 2040 1791 1725 2033 3961 1840 1566 2016 1850 1564 1435 2095
#  2230 274 1010 2080 2094 2034 452 1572 3920 272 2030 489 262 141 1450 4800
#  3400 499 841 840 1680 1505 2111 492 1670 2110 480 1235 493 1525 1631 1651
#  2019 1510 1370 1650 1611 '142B' 9901 1440 1626 1512 1530 2240 1511 1515
#  1627 1610 1520 451 1230 1630 5005 1697 3720 2070 3740 490 1622 1621]
# ----------------------------------------------------------------------
# unique values in Primary Type column
# ['ASSAULT' 'HOMICIDE' 'BURGLARY' 'BATTERY' 'THEFT' 'CRIMINAL DAMAGE'
#  'DECEPTIVE PRACTICE' 'CRIMINAL SEXUAL ASSAULT'
#  'OFFENSE INVOLVING CHILDREN' 'MOTOR VEHICLE THEFT' 'ROBBERY'
#  'SEX OFFENSE' 'OTHER OFFENSE' 'WEAPONS VIOLATION' 'STALKING'
#  'CRIMINAL TRESPASS' 'PROSTITUTION' 'ARSON' 'NARCOTICS' 'KIDNAPPING'
#  'CONCEALED CARRY LICENSE VIOLATION' 'INTERFERENCE WITH PUBLIC OFFICER'
#  'PUBLIC PEACE VIOLATION' 'OBSCENITY' 'LIQUOR LAW VIOLATION'
#  'INTIMIDATION' 'HUMAN TRAFFICKING' 'GAMBLING' 'CRIM SEXUAL ASSAULT'
#  'OTHER NARCOTIC VIOLATION' 'NON-CRIMINAL' 'PUBLIC INDECENCY' 'RITUALISM'
#  'DOMESTIC VIOLENCE']
# ----------------------------------------------------------------------
# unique values in Description column
# ['SIMPLE' 'FIRST DEGREE MURDER' 'UNLAWFUL ENTRY'
#  'AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY'
#  '$500 AND UNDER' 'TO VEHICLE' 'FINANCIAL IDENTITY THEFT OVER $ 300'
#  'NON-AGGRAVATED' 'TO PROPERTY' 'OVER $500' 'FORGERY' 'FROM BUILDING'
#  'BOGUS CHECK' 'CHILD ABDUCTION' 'AUTOMOBILE'
#  'ATTEMPT - FINANCIAL IDENTITY THEFT' 'ARMED - HANDGUN' 'PREDATORY'
#  'VEHICULAR HIJACKING' 'SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER'
#  'INDECENT SOLICITATION OF A CHILD' 'HARASSMENT BY ELECTRONIC MEANS'
#  'AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'
#  'SEXUAL EXPLOITATION OF A CHILD' 'AGGRAVATED CRIMINAL SEXUAL ABUSE'
#  'RECKLESS FIREARM DISCHARGE' 'CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'
#  'DOMESTIC BATTERY SIMPLE'
#  'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER' 'CYBERSTALKING'
#  'AGGRAVATED - OTHER' 'RETAIL THEFT' 'TO STATE SUP LAND'
#  'THEFT OF LOST / MISLAID PROPERTY' 'TO LAND' 'ATTEMPT - AUTOMOBILE'
#  'AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON'
#  'OTHER VEHICLE OFFENSE' 'FALSE / STOLEN / ALTERED TRP'
#  'AGGRAVATED - KNIFE / CUTTING INSTRUMENT'
#  'VEHICLE TITLE / REGISTRATION OFFENSE' 'AGGRAVATED - HANDGUN'
#  'STRONG ARM - NO WEAPON' 'SOLICITING FOR BUSINESS'
#  'ILLEGAL USE CASH CARD' 'BY FIRE' 'TO STATE SUPPORTED PROPERTY'
#  'TELEPHONE THREAT' 'ATTEMPT FORCIBLE ENTRY' 'FORCIBLE ENTRY'
#  'VIOLATE ORDER OF PROTECTION' 'POSSESS - CRACK' 'TO RESIDENCE'
#  'THEFT / RECOVERY - AUTOMOBILE'
#  'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY'
#  'ENDANGERING LIFE / HEALTH OF CHILD' 'UNLAWFUL RESTRAINT' 'AGGRAVATED'
#  'ARMED - OTHER FIREARM' 'ARMED - OTHER DANGEROUS WEAPON'
#  'CRIMINAL SEXUAL ABUSE' 'FRAUD OR CONFIDENCE GAME'
#  'AGGRAVATED - OTHER DANGEROUS WEAPON' 'PROHIBITED PLACES' 'OTHER OFFENSE'
#  'UNLAWFUL POSSESSION - HANDGUN' 'COUNTERFEITING DOCUMENT'
#  'TO CITY OF CHICAGO PROPERTY' 'THEFT OF LABOR / SERVICES'
#  'POSSESS - HEROIN (WHITE)' 'CREDIT CARD FRAUD'
#  'RESIST / OBSTRUCT / DISARM OFFICER' 'AGGRAVATED VEHICULAR HIJACKING'
#  'NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES'
#  'THEFT BY LESSEE, MOTOR VEHICLE' 'BOMB THREAT'
#  'FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON'
#  'AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY' 'OTHER VIOLATION'
#  'CYCLE, SCOOTER, BIKE WITH VIN' 'CHILD ABUSE'
#  'POSSESS - HEROIN (BLACK TAR)' 'ATTEMPT ARMED - HANDGUN'
#  'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY'
#  'POCKET-PICKING' 'UNLAWFUL USE - OTHER FIREARM'
#  'AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY'
#  'POSSESS - BARBITURATES' 'OTHER CRIME AGAINST PERSON'
#  'ATTEMPT AGGRAVATED' 'HOME INVASION' 'ILLEGAL POSSESSION CASH CARD'
#  'LICENSE VIOLATION' 'STOLEN PROPERTY BUY / RECEIVE / POSSESS'
#  'HARASSMENT BY TELEPHONE' 'POSSESS - CANNABIS MORE THAN 30 GRAMS'
#  'FINANCIAL IDENTITY THEFT $300 AND UNDER'
#  'ATTEMPT - CYCLE, SCOOTER, BIKE WITH VIN'
#  'SOLICIT NARCOTICS ON PUBLIC WAY' 'COMPUTER FRAUD' 'POSSESS - COCAINE'
#  'POSSESS - SYNTHETIC DRUGS' 'VIOLATION OF STALKING NO CONTACT ORDER'
#  'AGGRAVATED FINANCIAL IDENTITY THEFT'
#  'UNLAWFUL USE - OTHER DANGEROUS WEAPON'
#  'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS'
#  'AGGRAVATED OF A SENIOR CITIZEN' 'EMBEZZLEMENT' 'CHILD PORNOGRAPHY'
#  'ATTEMPT THEFT' 'COUNTERFEIT CHECK' 'OTHER' 'PUBLIC INDECENCY'
#  'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT'
#  'GUN OFFENDER - ANNUAL REGISTRATION' 'FALSE POLICE REPORT'
#  'FOUND SUSPECT NARCOTICS'
#  'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON'
#  'AGGRAVATED DOMESTIC BATTERY - HANDGUN' 'AGGRAVATED - OTHER FIREARM'
#  'OBSTRUCTING SERVICE' 'GUN OFFENDER - DUTY TO REGISTER'
#  'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY' 'ATTEMPT ARSON'
#  'CRIMINAL DEFACEMENT' 'POSSESSION OF BURGLARY TOOLS'
#  'ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT' 'RECKLESS CONDUCT'
#  'PURSE-SNATCHING' 'VIOLATION GPS MONITORING DEVICE'
#  'AGGRAVATED OF A CHILD' 'POSSESS - CANNABIS 30 GRAMS OR LESS'
#  'ANIMAL ABUSE / NEGLECT' 'OBSCENE TELEPHONE CALLS'
#  'ATTEMPT STRONG ARM - NO WEAPON'
#  'THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN'
#  'AGGRAVATED POLICE OFFICER - HANDGUN' 'OTHER CRIME INVOLVING PROPERTY'
#  'KIDNAPPING' 'OBSTRUCTING JUSTICE'
#  'SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR' 'EMPLOY MINOR'
#  'ARMED - KNIFE / CUTTING INSTRUMENT' 'POSSESSION OF DRUG EQUIPMENT'
#  'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY'
#  'OF AN UNBORN CHILD' 'SELL / GIVE / DELIVER LIQUOR TO MINOR'
#  'INTIMIDATION' 'POSSESS - HALLUCINOGENS' 'POSSESS - PCP'
#  'CHILD ABDUCTION / STRANGER' 'DECEPTIVE COLLECTION PRACTICES'
#  'UNLAWFUL POSSESSION - AMMUNITION' 'UNLAWFUL USE - HANDGUN'
#  'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT'
#  'AGGRAVATED COMPUTER TAMPERING' 'CONTRIBUTE TO THE DELINQUENCY OF CHILD'
#  'TRUCK, BUS, MOTOR HOME' 'ARMED: HANDGUN'
#  'AGGRAVATED P.O. - HANDS, FISTS, FEET, SERIOUS INJURY'
#  'SEX OFFENDER - FAIL TO REGISTER' 'INVOLUNTARY SERVITUDE'
#  'VIOLATION OF CIVIL NO CONTACT ORDER' 'GAME/DICE'
#  'OBSTRUCTING IDENTIFICATION' 'ATTEMPT NON-AGGRAVATED'
#  'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT'
#  'UNAUTHORIZED VIDEOTAPING' 'MANUFACTURE / DELIVER -  HEROIN (WHITE)'
#  'LIQUOR LICENSE VIOLATION' 'SOLICIT ON PUBLIC WAY'
#  'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON'
#  'CYCLE, SCOOTER, BIKE NO VIN' 'VIOLENT OFFENDER - DUTY TO REGISTER'
#  'UNLAWFUL USE OF A COMPUTER' 'CHILD ABANDONMENT'
#  'POSSESS - METHAMPHETAMINE' 'ESCAPE' 'ARMED VIOLENCE' 'OBSCENE MATTER'
#  'SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS'
#  'ATTEMPT ARMED - OTHER DANGEROUS WEAPON' 'EXTORTION' 'POSS: COCAINE'
#  'UNLAWFUL SALE - HANDGUN' 'OTHER WEAPONS VIOLATION'
#  'MANUFACTURE / DELIVER - CRACK'
#  'MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS'
#  'AGGRAVATED PROTECTED EMPLOYEE - HANDGUN' 'IMPERSONATION'
#  'POSS: HEROIN(WHITE)' 'POSS: CRACK'
#  'THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME'
#  'POSSESS - HEROIN (TAN / BROWN TAR)' 'UNLAWFUL VISITATION INTERFERENCE'
#  'FORFEIT PROPERTY' 'ALTER / FORGE PRESCRIPTION' 'SOLICIT OFF PUBLIC WAY'
#  'POSSESS FIREARM / AMMUNITION - NO FOID CARD'
#  'THEFT BY LESSEE, NON-MOTOR VEHICLE' 'DELIVERY CONTAINER THEFT'
#  'ATTEMPT AGGRAVATED - OTHER' 'ARSON THREAT'
#  'GUN OFFENDER - DUTY TO REPORT CHANGE OF INFORMATION'
#  'TAMPER WITH MOTOR VEHICLE' 'UNLAWFUL POSSESSION - OTHER FIREARM'
#  'MANUFACTURE / DELIVER - METHAMPHETAMINE' 'TO AIRPORT' 'PEEPING TOM'
#  'ARMED WHILE UNDER THE INFLUENCE' 'ATTEMPT ARMED - OTHER FIREARM'
#  'TIRE DEFLATION DEVICE DEPLOYMENT' 'PAROLE VIOLATION'
#  'AGGRAVATED: HANDGUN' 'UNLAWFUL USE / SALE OF AIR RIFLE'
#  'POSSESSION OF PORNOGRAPHIC PRINT'
#  'VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE' 'BOARD PLANE WITH WEAPON'
#  'POSSESS - AMPHETAMINES' 'CRIMINAL DRUG CONSPIRACY'
#  'THEFT / RECOVERY - CYCLE, SCOOTER, BIKE NO VIN'
#  'SEX OFFENDER - PROHIBITED ZONE' 'ATTEMPT CRIMINAL SEXUAL ABUSE'
#  'SEXUAL RELATIONS IN FAMILY' 'INSURANCE FRAUD' 'INSTITUTIONAL VANDALISM'
#  'MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR)'
#  'STRONGARM - NO WEAPON' 'ATTEMPT - TRUCK, BUS, MOTOR HOME'
#  'HAZARDOUS MATERIALS VIOLATION' 'ATTEMPT AGGRAVATED - HANDGUN'
#  'ABUSE / NEGLECT - CARE FACILITY' 'MANU/DELIVER:CRACK' 'MOB ACTION'
#  'OBSCENITY' 'MANUFACTURE / DELIVER - COCAINE' 'RECKLESS HOMICIDE'
#  'COMMERCIAL SEX ACTS' 'FORCIBLE DETENTION' 'ATT: AUTOMOBILE'
#  '$300 AND UNDER' 'MANUFACTURE / DELIVER - BARBITURATES'
#  'MANUFACTURE / DELIVER - SYNTHETIC DRUGS' 'EAVESDROPPING'
#  'ATTEMPT - CYCLE, SCOOTER, BIKE NO VIN'
#  'OTHER ARSON / EXPLOSIVE INCIDENT' 'PUBLIC DEMONSTRATION'
#  'INTERFERENCE JUDICIAL PROCESS' 'BIGAMY' 'ILLEGAL POSSESSION BY MINOR'
#  'AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM'
#  'VIOLENT OFFENDER - FAIL TO REGISTER NEW ADDRESS'
#  'MANUFACTURE / DELIVER - AMPHETAMINES'
#  'VIOLENT OFFENDER - ANNUAL REGISTRATION' 'OTHER PROSTITUTION OFFENSE'
#  'ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT'
#  'MANUFACTURE / DELIVER - HALLUCINOGEN' 'BRIBERY' 'INTOXICATING COMPOUNDS'
#  'VIOLATION OF SMOKING BAN' 'SALE / DELIVER - DRUG PARAPHERNALIA'
#  'CONCEALED CARRY LICENSE REVOCATION' 'FORNICATION'
#  'AGG: FINANCIAL ID THEFT' 'PAY TV SERVICE OFFENSES' 'LICENSED PREMISE'
#  'AGGRAVATED POLICE OFFICER - OTHER FIREARM' 'FALSE FIRE ALARM'
#  'POSSESSION - EXPLOSIVE / INCENDIARY DEVICE'
#  'FROM COIN-OPERATED MACHINE OR DEVICE' 'AGGRAVATED OF AN UNBORN CHILD'
#  'ARSONIST - ANNUAL REGISTRATION'
#  'ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE'
#  'AGG CRIM SEX ABUSE FAM MEMBER' 'MANU/DELIVER: HEROIN (WHITE)'
#  'INTERFERE WITH EMERGENCY EQUIPMENT' 'CRIM SEX ABUSE BY FAM MEMBER'
#  'AGG CRIMINAL SEXUAL ABUSE' 'POSS: CANNABIS MORE THAN 30GMS'
#  'POSSESS - LOOK-ALIKE DRUGS' 'SEX ASSLT OF CHILD BY FAM MBR'
#  'HARBOR RUNAWAY' 'AGG SEX ASSLT OF CHILD FAM MBR'
#  'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON'
#  'FINAN EXPLOIT-ELDERLY/DISABLED' 'ATT CRIM SEXUAL ABUSE'
#  'AGGRAVATED: OTHER' 'CONTRIBUTE TO THE CRIMINAL DELINQUENCY OF CHILD'
#  'MANUFACTURE / DELIVER - SYNTHETIC MARIJUANA'
#  'MANU/DEL:CANNABIS 10GM OR LESS' 'POSS: HALLUCINOGENS'
#  'THEFT/RECOVERY: AUTOMOBILE' 'INDECENT SOLICITATION/CHILD'
#  'INTIMIDATION OF LAW ENFORCEMENT OFFICIAL'
#  'DELIVER CANNABIS TO PERSON UNDER 18' 'INDECENT SOLICITATION OF AN ADULT'
#  'MANUFACTURE / DELIVER - PCP' 'CANNABIS PLANT'
#  'CRIMINAL TRANSMISSION OF HIV'
#  'UNLAWFUL SALE - DELIVERY OF FIREARM AT SCHOOL'
#  'ATTEMPT POSSESSION NARCOTICS'
#  'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY'
#  'ILLEGAL CONSUMPTION BY MINOR'
#  'ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON' 'ALTER/FORGE PRESCRIPTION'
#  'FALSE/STOLEN/ALTERED TRP' 'BY EXPLOSIVE'
#  'FAILURE TO MAINTAIN RECORDS - CONTROLLED SUBSTANCES'
#  'ATTEMPT POSSESSION CANNABIS' 'POSSESSION - SYNTHETIC MARIJUANA'
#  'AGGRAVATED: OTHER DANG WEAPON' 'POSS: CANNABIS 30GMS OR LESS' 'ADULTRY'
#  'OFFICIAL MISCONDUCT' 'ATTEMPT AGGRAVATED - OTHER FIREARM'
#  'SEX OFFENDER: FAIL REG NEW ADD'
#  'MANUFACTURE / DELIVER - LOOK-ALIKE DRUG' 'THEFT OF LABOR/SERVICES'
#  'AGGRAVATED DOMESTIC BATTERY - OTHER FIREARM' 'INVOLUNTARY MANSLAUGHTER'
#  'DEFACE IDENTIFICATION MARKS OF FIREARM' 'MONEY LAUNDERING' 'LOOTING'
#  'AGG: HANDS/FIST/FEET NO/MINOR INJURY' 'AGGRAVATED:KNIFE/CUTTING INSTR'
#  'ENDANGERING LIFE/HEALTH CHILD' 'VIO BAIL BOND: DOM VIOLENCE'
#  'AGGRAVATED DOMESTIC BATTERY' 'TO STATE SUP PROP'
#  'FINANCIAL ID THEFT:$300 &UNDER'
#  'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST'
#  'FINANCIAL ID THEFT: OVER $300' 'FINANCIAL IDENTITY THEFT: $300 & UNDER'
#  'NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES'
#  'ATTEMPT: STRONGARM-NO WEAPON' 'ATTEMPT: ARMED-HANDGUN'
#  'AGGRAVATED: OTHER FIREARM' 'POSS: SYNTHETIC DRUGS'
#  'CHILD ABDUCTION/STRANGER' 'POSS: HEROIN(BRN/TAN)'
#  'AGG PO HANDS NO/MIN INJURY' 'ATTEMPT: AGGRAVATED' 'SOLICIT FOR BUSINESS'
#  'ARMED:KNIFE/CUTTING INSTRUMENT' 'CALL OPERATION'
#  'SOLICIT NARCOTICS ON PUBLICWAY' 'UNLAWFUL POSS OF HANDGUN'
#  'UNLAWFUL USE OTHER DANG WEAPON' 'THEFT BY LESSEE,NON-VEH'
#  'MANU/DEL:CANNABIS OVER 10 GMS' 'UNLAWFUL POSS AMMUNITION'
#  'SEX OFFENDER: FAIL TO REGISTER' 'THEFT OF LOST/MISLAID PROP'
#  'UNLAWFUL INTERFERE/VISITATION' 'THEFT BY LESSEE,MOTOR VEH'
#  'ARMED: OTHER DANGEROUS WEAPON' 'SELL/GIVE/DEL LIQUOR TO MINOR'
#  'SALE/DEL HYPODERMIC NEEDLE' 'AGGRAVATED: KNIFE/CUT INSTR'
#  'AGG RITUAL MUT:KNIFE/CUTTING I' 'AGG PRO.EMP:KNIFE/CUTTING INST'
#  'ATT: TRUCK, BUS, MOTOR HOME' 'ATTEMPT: ARMED-KNIFE/CUT INSTR'
#  'CYCLE, SCOOTER, BIKE W-VIN' 'STOLEN PROP: BUY/RECEIVE/POS.'
#  'MANU/DELIVER:PCP' 'UNLAWFUL POSS OTHER FIREARM'
#  'THEFT/RECOVERY: TRUCK,BUS,MHOME' 'POSS: PCP'
#  'ATTEMPT: ARMED-OTHER DANG WEAP' 'GAME/AMUSEMENT DEVICE'
#  'ATTEMPT: ARMED-OTHER FIREARM' 'MANU/DELIVER:LOOK-ALIKE DRUG'
#  'UNLAWFUL USE HANDGUN' 'POS: HYPODERMIC NEEDLE' 'AGG PRO.EMP: HANDGUN'
#  'UNLAWFUL USE/SALE AIR RIFLE' 'UNLAWFUL USE OTHER FIREARM'
#  'ATTEMPT AGG: KNIFE/CUT INSTR' 'PRO EMP HANDS NO/MIN INJURY'
#  'CONTRIBUTE DELINQUENCY OF A CHILD' 'AGGRAVATED PO: HANDGUN'
#  'ARMED: OTHER FIREARM' 'RESIST/OBSTRUCT/DISARM OFFICER'
#  'UNLAWFUL USE OF RECORDED SOUND' 'ATTEMPT AGG: OTHER DANG WEAPON'
#  'UNLAWFUL SALE HANDGUN' 'AGGRAVATED PO: KNIFE/CUT INSTR'
#  'MANU/DELIVER:COCAINE' 'ATT AGG CRIMINAL SEXUAL ABUSE'
#  'AGG RITUAL MUT:OTH DANG WEAPON' 'PATRONIZING A PROSTITUTE'
#  'WIREROOM/SPORTS' 'POSS FIREARM/AMMO:NO FOID CARD' 'GAME/CARDS'
#  'AGGRAVATED PO: OTHER DANG WEAP' 'MANU/DELIVER:HEROIN(BLACK TAR)'
#  'POSS: AMPHETAMINES' 'CAB OPERATION' 'MANU/DELIVER: HALLUCINOGEN'
#  'POSS: BARBITUATES' 'POSS: HEROIN(BLACK TAR)' 'TO FIRE FIGHT.APP.EQUIP'
#  'POSS: LOOK-ALIKE DRUGS' 'MANU/DELIVER: HEROIN(BRN/TAN)'
#  'VIOL CHARITABLE GAME ACT' 'AGGRAVATED PO: OTHER FIREARM'
#  'DELIVER CANNABIS TO PERSON <18' 'MANU/DELIVER:AMPHETAMINES'
#  'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN' 'MANU/DELIVER:BARBITUATES'
#  'INDECENT SOLICITATION/ADULT' 'AGGRAVATED PO:KNIFE/CUT INSTR'
#  'BOOKMAKING/SPORTS' 'UNLAWFUL SALE OTHER FIREARM' 'DOMESTIC VIOLENCE'
#  'REGISTER OF SALES BY DEALER' 'AGG PRO.EMP: OTHER DANG WEAPON'
#  'ILLEGAL ILL LOTTERY' 'ATTEMPT AGG: HANDGUN' 'SOLICIT FOR PROSTITUTE'
#  'MANU/DELIVER:SYNTHETIC DRUGS' 'ATTEMPT AGG: OTHER' 'PIMPING'
#  'MINOR MISREPRESENT AGE' 'IN TAVERN' 'PANDERING'
#  'POS: EXPLOSIVE/INCENDIARY DEV' 'LOTTERY/OTHER'
#  'OTHER ARSON/EXPLOSIVE INCIDENT' 'ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN'
#  'BOOKMAKING/HORSES' 'OVER $300' 'KEEP PLACE OF PROSTITUTION'
#  'SALE/DIST OBSCENE MAT TO MINOR' 'FINANCIAL IDENTITY THEFT: OVER $300'
#  'POSS. KEYS OR DEV.TO COIN MACH' 'WIREROOM/HORSES'
#  'ATT AGG CRIM SEXUAL ABUSE' 'DEFACE IDENT MARKS OF FIREARM'
#  'POLICY/OTHER' 'REFUSING TO AID AN OFFICER' 'DEL CONT SUBS TO PERSON <18'
#  'CONCEALING/AIDING A FUGITIVE' 'SEX RELATION IN FAMILY'
#  'AGG RITUAL MUT:HANDGUN' 'SEX OFFENDER: PROHIBITED ZONE'
#  'BOLITA OR BOLI PUL/WRITER' 'BOLITA OR BOLI PUL/RUNNER']
# ----------------------------------------------------------------------
# unique values in Location Description column
# ['OTHER' 'STREET' 'PARKING LOT' 'APARTMENT' 'SMALL RETAIL STORE'
#  'GAS STATION' 'PARKING LOT / GARAGE (NON RESIDENTIAL)'
#  'RESIDENCE - GARAGE' 'RESIDENCE - PORCH / HALLWAY' 'CURRENCY EXCHANGE'
#  'RESIDENCE' 'AUTO / BOAT / RV DEALERSHIP'
#  'POLICE FACILITY / VEHICLE PARKING LOT' 'DEPARTMENT STORE'
#  'CHA PARKING LOT / GROUNDS' 'RESTAURANT' 'GROCERY FOOD STORE'
#  'APPLIANCE STORE' 'CAR WASH' 'HOSPITAL BUILDING / GROUNDS'
#  'COMMERCIAL / BUSINESS OFFICE' 'SIDEWALK' 'DRIVEWAY - RESIDENTIAL'
#  'OTHER (SPECIFY)' 'PARK PROPERTY' 'ALLEY' 'BANK' 'DRUG STORE'
#  'VEHICLE NON-COMMERCIAL' 'RESIDENCE - YARD (FRONT / BACK)'
#  'BAR OR TAVERN' 'LAKEFRONT / WATERFRONT / RIVERBANK'
#  'SCHOOL - PUBLIC BUILDING' 'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA'
#  'NURSING / RETIREMENT HOME' 'HOTEL / MOTEL' 'CONVENIENCE STORE'
#  'CTA BUS STOP' 'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA'
#  'GOVERNMENT BUILDING / PROPERTY' 'TAVERN / LIQUOR STORE' 'CTA PLATFORM'
#  'COLLEGE / UNIVERSITY - RESIDENCE HALL'
#  'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA' 'VEHICLE - COMMERCIAL'
#  'SCHOOL - PUBLIC GROUNDS' 'WAREHOUSE' 'CTA TRAIN' nan 'CTA BUS'
#  'ATM (AUTOMATIC TELLER MACHINE)'
#  'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA' 'CONSTRUCTION SITE'
#  'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA' 'ATHLETIC CLUB'
#  'CHURCH / SYNAGOGUE / PLACE OF WORSHIP' 'CTA STATION' 'CEMETARY'
#  'ABANDONED BUILDING' 'VACANT LOT / LAND'
#  'CHA HALLWAY / STAIRWELL / ELEVATOR' 'SCHOOL - PRIVATE GROUNDS'
#  'CHA APARTMENT' 'CTA TRACKS - RIGHT OF WAY' 'GAS STATION DRIVE/PROP.'
#  'BARBERSHOP' 'BOAT / WATERCRAFT' 'TAXICAB' 'ANIMAL HOSPITAL'
#  'SCHOOL - PRIVATE BUILDING' 'MEDICAL / DENTAL OFFICE'
#  'SPORTS ARENA / STADIUM' 'OTHER COMMERCIAL TRANSPORTATION'
#  'AIRPORT PARKING LOT' 'MOVIE HOUSE / THEATER'
#  'AIRPORT BUILDING NON-TERMINAL - SECURE AREA'
#  'CTA PARKING LOT / GARAGE / OTHER PROPERTY' 'DAY CARE CENTER'
#  'HIGHWAY / EXPRESSWAY' 'FACTORY / MANUFACTURING BUILDING'
#  'FEDERAL BUILDING' 'HOUSE' 'PAWN SHOP' 'CREDIT UNION' 'AIRCRAFT'
#  'FIRE STATION' 'COLLEGE / UNIVERSITY - GROUNDS' 'LIBRARY'
#  'VEHICLE - DELIVERY TRUCK' 'HALLWAY'
#  'VEHICLE - OTHER RIDE SHARE SERVICE (LYFT, UBER, ETC.)'
#  'OTHER RAILROAD PROPERTY / TRAIN DEPOT' 'AUTO' 'COIN OPERATED MACHINE'
#  'AIRPORT EXTERIOR - SECURE AREA' 'CLEANING STORE'
#  'AIRPORT TRANSPORTATION SYSTEM (ATS)' 'JAIL / LOCK-UP FACILITY' 'BRIDGE'
#  'AIRPORT EXTERIOR - NON-SECURE AREA' 'AIRPORT VENDING ESTABLISHMENT'
#  'AIRPORT/AIRCRAFT' 'GARAGE' 'KENNEL' 'YARD' 'FOREST PRESERVE'
#  'BOWLING ALLEY' 'VEHICLE - COMMERCIAL: ENTERTAINMENT / PARTY BUS'
#  'GANGWAY' 'AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA' 'RETAIL STORE'
#  'PORCH' 'DRIVEWAY' 'CHA PARKING LOT/GROUNDS' 'HOTEL' 'RESIDENCE-GARAGE'
#  'CHA HALLWAY' 'PARKING LOT/GARAGE(NON.RESID.)' 'VACANT LOT'
#  'VEHICLE - COMMERCIAL: TROLLEY BUS' 'TAVERN/LIQUOR STORE'
#  'CHURCH/SYNAGOGUE/PLACE OF WORSHIP' 'CTA SUBWAY STATION'
#  'RESIDENTIAL YARD (FRONT/BACK)' 'GOVERNMENT BUILDING/PROPERTY'
#  'SCHOOL, PUBLIC, BUILDING' 'STAIRWELL' 'POLICE FACILITY/VEH PARKING LOT'
#  'VEHICLE-COMMERCIAL' 'OTHER RAILROAD PROP / TRAIN DEPOT'
#  'SAVINGS AND LOAN' 'TAVERN' 'VESTIBULE' 'CTA "L" TRAIN' 'DUMPSTER'
#  'BASEMENT' 'CHA GROUNDS' 'MEDICAL/DENTAL OFFICE'
#  'NURSING HOME/RETIREMENT HOME' 'LIQUOR STORE' 'RESIDENCE PORCH/HALLWAY'
#  'BEACH' 'HOSPITAL' 'POOL ROOM' 'OFFICE' 'CHA LOBBY' 'SCHOOL YARD'
#  'SCHOOL, PRIVATE, GROUNDS' 'HOTEL/MOTEL' 'SCHOOL, PRIVATE, BUILDING'
#  'SCHOOL, PUBLIC, GROUNDS' 'HOSPITAL BUILDING/GROUNDS'
#  'CHA HALLWAY/STAIRWELL/ELEVATOR' 'COLLEGE/UNIVERSITY RESIDENCE HALL'
#  'SPORTS ARENA/STADIUM' 'GARAGE/AUTO REPAIR' 'NURSING HOME'
#  'COLLEGE/UNIVERSITY GROUNDS' 'DELIVERY TRUCK' 'VACANT LOT/LAND'
#  'FACTORY/MANUFACTURING BUILDING' 'ROOMING HOUSE' 'WOODED AREA' 'TRUCK'
#  'CHA PARKING LOT' 'MOVIE HOUSE/THEATER' 'CHA STAIRWELL' 'MOTEL' 'CLUB'
#  'PRAIRIE' 'YMCA' 'CTA PROPERTY' 'RAILROAD PROPERTY'
#  'EXPRESSWAY EMBANKMENT' 'LAKE' 'BARBER SHOP/BEAUTY SALON' 'BANQUET HALL'
#  'ELEVATOR' 'HIGHWAY/EXPRESSWAY' 'CHA ELEVATOR' 'RIVER BANK' 'COUNTY JAIL'
#  'CHURCH' 'NEWSSTAND' 'SEWER' 'CTA "L" PLATFORM' 'TAXI CAB' 'COACH HOUSE'
#  'LAGOON' 'TRUCKING TERMINAL' 'CHURCH PROPERTY'
#  'LAKEFRONT/WATERFRONT/RIVERBANK' 'ROOF' 'RIVER' 'GOVERNMENT BUILDING'
#  'POOLROOM' 'CHA BREEZEWAY' 'LIVERY STAND OFFICE' 'CHA PLAY LOT'
#  'BOAT/WATERCRAFT' 'CLEANERS/LAUNDROMAT' 'TRAILER' 'POLICE FACILITY'
#  'JUNK YARD/GARBAGE DUMP' 'PUBLIC GRAMMAR SCHOOL' 'FUNERAL PARLOR'
#  'LAUNDRY ROOM' 'PUBLIC HIGH SCHOOL' 'LIVERY AUTO' 'FACTORY'
#  'LOADING DOCK']
# ----------------------------------------------------------------------
# unique values in FBI Code column
# ['08A' '01A' 5 '08B' 6 14 11 2 10 26 7 3 17 15 '04B' '04A' 16 9 18 20 24
#  13 12 22 19 '01B' 27]
# ----------------------------------------------------------------------
# unique values in Location column
# [nan '(41.917838056, -87.755968972)' '(41.995219444, -87.713354912)' ...
#  '(41.889640185, -87.616537833)' '(41.969226208, -87.652763964)'
#  '(41.938448908, -87.717224032)']
# ----------------------------------------------------------------------

# %%
# unique_values = df['Block'].unique()
# for value in unique_values:
#     matches = process.extract(value, unique_values, limit=5, scorer=fuzz.partial_ratio)
#     print(f"{value}: {matches}")

# %%
grouped_descriptions = df.groupby('IUCR')['Description'].unique()
descriptions = grouped_descriptions[grouped_descriptions.apply(len) > 1]
pd.set_option('display.max_colwidth', None)
print(descriptions)
# Out:
# IUCR
# 261                                                                                   [AGGRAVATED - HANDGUN, AGGRAVATED: HANDGUN]
# 262                                                                       [AGGRAVATED - OTHER FIREARM, AGGRAVATED: OTHER FIREARM]
# 263                                                        [AGGRAVATED - KNIFE / CUTTING INSTRUMENT, AGGRAVATED: KNIFE/CUT INSTR]
# 264                                                          [AGGRAVATED - OTHER DANGEROUS WEAPON, AGGRAVATED: OTHER DANG WEAPON]
# 265                                                                                       [AGGRAVATED - OTHER, AGGRAVATED: OTHER]
# 271                                                                          [ATTEMPT AGGRAVATED - HANDGUN, ATTEMPT AGG: HANDGUN]
# 273                                               [ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT, ATTEMPT AGG: KNIFE/CUT INSTR]
# 274                                                 [ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON, ATTEMPT AGG: OTHER DANG WEAPON]
# 275                                                                              [ATTEMPT AGGRAVATED - OTHER, ATTEMPT AGG: OTHER]
# 312                                                          [ARMED - KNIFE / CUTTING INSTRUMENT, ARMED:KNIFE/CUTTING INSTRUMENT]
# 313                                                               [ARMED - OTHER DANGEROUS WEAPON, ARMED: OTHER DANGEROUS WEAPON]
# 320                                                                               [STRONG ARM - NO WEAPON, STRONGARM - NO WEAPON]
# 331                                                                                     [ATTEMPT AGGRAVATED, ATTEMPT: AGGRAVATED]
# 334                                                  [ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT, ATTEMPT: ARMED-KNIFE/CUT INSTR]
# 337                                                      [ATTEMPT ARMED - OTHER DANGEROUS WEAPON, ATTEMPT: ARMED-OTHER DANG WEAP]
# 340                                                                [ATTEMPT STRONG ARM - NO WEAPON, ATTEMPT: STRONGARM-NO WEAPON]
# 420                                                     [AGGRAVATED - KNIFE / CUTTING INSTRUMENT, AGGRAVATED:KNIFE/CUTTING INSTR]
# 430                                                          [AGGRAVATED - OTHER DANGEROUS WEAPON, AGGRAVATED: OTHER DANG WEAPON]
# 440                                    [AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY, AGG: HANDS/FIST/FEET NO/MINOR INJURY]
# 450                                                                 [AGGRAVATED POLICE OFFICER - HANDGUN, AGGRAVATED PO: HANDGUN]
# 452                                      [AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT, AGGRAVATED PO: KNIFE/CUT INSTR]
# 453                                          [AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON, AGGRAVATED PO: OTHER DANG WEAP]
# 454                                         [AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY, AGG PO HANDS NO/MIN INJURY]
# 482                                  [AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT, AGG PRO.EMP:KNIFE/CUTTING INST]
# 483                                      [AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON, AGG PRO.EMP: OTHER DANG WEAPON]
# 484                                     [PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY, PRO EMP HANDS NO/MIN INJURY]
# 496                   [AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT, AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST]
# 497                        [AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON, AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON]
# 498     [AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY, AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY]
# 520                                                     [AGGRAVATED - KNIFE / CUTTING INSTRUMENT, AGGRAVATED:KNIFE/CUTTING INSTR]
# 530                                                          [AGGRAVATED - OTHER DANGEROUS WEAPON, AGGRAVATED: OTHER DANG WEAPON]
# 545                                     [PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY, PRO EMP HANDS NO/MIN INJURY]
# 550                                                                 [AGGRAVATED POLICE OFFICER - HANDGUN, AGGRAVATED PO: HANDGUN]
# 551                                                     [AGGRAVATED POLICE OFFICER - OTHER FIREARM, AGGRAVATED PO: OTHER FIREARM]
# 552                                       [AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT, AGGRAVATED PO:KNIFE/CUT INSTR]
# 553                                          [AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON, AGGRAVATED PO: OTHER DANG WEAP]
# 554                                       [AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY, AGG PO HANDS NO/MIN INJURY]
# 810                                                                                                        [OVER $500, OVER $300]
# 820                                                                                              [$500 AND UNDER, $300 AND UNDER]
# 840                                                          [FINANCIAL ID THEFT: OVER $300, FINANCIAL IDENTITY THEFT: OVER $300]
# 841                                                      [FINANCIAL ID THEFT:$300 &UNDER, FINANCIAL IDENTITY THEFT: $300 & UNDER]
# 917                                                                   [CYCLE, SCOOTER, BIKE WITH VIN, CYCLE, SCOOTER, BIKE W-VIN]
# 920                                                                                       [ATTEMPT - AUTOMOBILE, ATT: AUTOMOBILE]
# 925                                                               [ATTEMPT - TRUCK, BUS, MOTOR HOME, ATT: TRUCK, BUS, MOTOR HOME]
# 927                                                [ATTEMPT - CYCLE, SCOOTER, BIKE WITH VIN, ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN]
# 930                                                                   [THEFT / RECOVERY - AUTOMOBILE, THEFT/RECOVERY: AUTOMOBILE]
# 935                                                 [THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME, THEFT/RECOVERY: TRUCK,BUS,MHOME]
# 937                                [THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN, THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN]
# 1030                                                  [POSSESSION - EXPLOSIVE / INCENDIARY DEVICE, POS: EXPLOSIVE/INCENDIARY DEV]
# 1195                                    [FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON, FINAN EXPLOIT-ELDERLY/DISABLED]
# 1200                                                     [STOLEN PROPERTY BUY / RECEIVE / POSSESS, STOLEN PROP: BUY/RECEIVE/POS.]
# 1205                                                                [THEFT BY LESSEE, NON-MOTOR VEHICLE, THEFT BY LESSEE,NON-VEH]
# 1206                                                                  [THEFT BY LESSEE, MOTOR VEHICLE, THEFT BY LESSEE,MOTOR VEH]
# 1210                                                                         [THEFT OF LABOR / SERVICES, THEFT OF LABOR/SERVICES]
# 1220                                                               [THEFT OF LOST / MISLAID PROPERTY, THEFT OF LOST/MISLAID PROP]
# 1340                                                                             [TO STATE SUPPORTED PROPERTY, TO STATE SUP PROP]
# 1450                                                      [DEFACE IDENTIFICATION MARKS OF FIREARM, DEFACE IDENT MARKS OF FIREARM]
# 1460                                                [POSSESS FIREARM / AMMUNITION - NO FOID CARD, POSS FIREARM/AMMO:NO FOID CARD]
# 1513                                                                              [SOLICITING FOR BUSINESS, SOLICIT FOR BUSINESS]
# 1541                                                [SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR, SALE/DIST OBSCENE MAT TO MINOR]
# 1562                                                                [AGGRAVATED CRIMINAL SEXUAL ABUSE, AGG CRIMINAL SEXUAL ABUSE]
# 1565                                                              [INDECENT SOLICITATION OF A CHILD, INDECENT SOLICITATION/CHILD]
# 1566                                                             [INDECENT SOLICITATION OF AN ADULT, INDECENT SOLICITATION/ADULT]
# 1580                                                                         [SEXUAL RELATIONS IN FAMILY, SEX RELATION IN FAMILY]
# 1581                  [NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES, NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES]
# 1590                                                    [ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE, ATT AGG CRIMINAL SEXUAL ABUSE]
# 1710                                                          [ENDANGERING LIFE / HEALTH OF CHILD, ENDANGERING LIFE/HEALTH CHILD]
# 1720                                                  [CONTRIBUTE TO THE DELINQUENCY OF CHILD, CONTRIBUTE DELINQUENCY OF A CHILD]
# 1751                                                       [CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER, CRIM SEX ABUSE BY FAM MEMBER]
# 1752                                           [AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER, AGG CRIM SEX ABUSE FAM MEMBER]
# 1753                                                    [SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER, SEX ASSLT OF CHILD BY FAM MBR]
# 1754                                        [AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER, AGG SEX ASSLT OF CHILD FAM MBR]
# 1792                                                                       [CHILD ABDUCTION / STRANGER, CHILD ABDUCTION/STRANGER]
# 1811                                                          [POSSESS - CANNABIS 30 GRAMS OR LESS, POSS: CANNABIS 30GMS OR LESS]
# 1812                                                      [POSSESS - CANNABIS MORE THAN 30 GRAMS, POSS: CANNABIS MORE THAN 30GMS]
# 1821                                          [MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS, MANU/DEL:CANNABIS 10GM OR LESS]
# 1822                                              [MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS, MANU/DEL:CANNABIS OVER 10 GMS]
# 1840                                                        [DELIVER CANNABIS TO PERSON UNDER 18, DELIVER CANNABIS TO PERSON <18]
# 2010                                                            [MANUFACTURE / DELIVER - AMPHETAMINES, MANU/DELIVER:AMPHETAMINES]
# 2011                                                             [MANUFACTURE / DELIVER - BARBITURATES, MANU/DELIVER:BARBITUATES]
# 2012                                                                      [MANUFACTURE / DELIVER - COCAINE, MANU/DELIVER:COCAINE]
# 2013                                            [MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR), MANU/DELIVER: HEROIN(BRN/TAN)]
# 2014                                                      [MANUFACTURE / DELIVER -  HEROIN (WHITE), MANU/DELIVER: HEROIN (WHITE)]
# 2015                                                           [MANUFACTURE / DELIVER - HALLUCINOGEN, MANU/DELIVER: HALLUCINOGEN]
# 2016                                                                              [MANUFACTURE / DELIVER - PCP, MANU/DELIVER:PCP]
# 2017                                                                          [MANUFACTURE / DELIVER - CRACK, MANU/DELIVER:CRACK]
# 2018                                                      [MANUFACTURE / DELIVER - SYNTHETIC DRUGS, MANU/DELIVER:SYNTHETIC DRUGS]
# 2020                                                                                 [POSSESS - AMPHETAMINES, POSS: AMPHETAMINES]
# 2021                                                                                  [POSSESS - BARBITURATES, POSS: BARBITUATES]
# 2022                                                                                           [POSSESS - COCAINE, POSS: COCAINE]
# 2023                                                                  [POSSESS - HEROIN (TAN / BROWN TAR), POSS: HEROIN(BRN/TAN)]
# 2024                                                                              [POSSESS - HEROIN (WHITE), POSS: HEROIN(WHITE)]
# 2025                                                                               [POSSESS - HALLUCINOGENS, POSS: HALLUCINOGENS]
# 2026                                                                                                   [POSSESS - PCP, POSS: PCP]
# 2027                                                                                               [POSSESS - CRACK, POSS: CRACK]
# 2028                                                                           [POSSESS - SYNTHETIC DRUGS, POSS: SYNTHETIC DRUGS]
# 2029                                                                      [POSSESS - HEROIN (BLACK TAR), POSS: HEROIN(BLACK TAR)]
# 2030                                                      [MANUFACTURE / DELIVER - LOOK-ALIKE DRUG, MANU/DELIVER:LOOK-ALIKE DRUG]
# 2040                                                                         [POSSESS - LOOK-ALIKE DRUGS, POSS: LOOK-ALIKE DRUGS]
# 2090                                                                       [ALTER / FORGE PRESCRIPTION, ALTER/FORGE PRESCRIPTION]
# 2092                                                            [SOLICIT NARCOTICS ON PUBLIC WAY, SOLICIT NARCOTICS ON PUBLICWAY]
# 2210                                                       [SELL / GIVE / DELIVER LIQUOR TO MINOR, SELL/GIVE/DEL LIQUOR TO MINOR]
# 2900                                                              [UNLAWFUL USE / SALE OF AIR RIFLE, UNLAWFUL USE/SALE AIR RIFLE]
# 3710                                                         [RESIST / OBSTRUCT / DISARM OFFICER, RESIST/OBSTRUCT/DISARM OFFICER]
# 4255                                                            [UNLAWFUL VISITATION INTERFERENCE, UNLAWFUL INTERFERE/VISITATION]
# 4388                                                    [VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE, VIO BAIL BOND: DOM VIOLENCE]
# 4650                                                            [SEX OFFENDER - FAIL TO REGISTER, SEX OFFENDER: FAIL TO REGISTER]
# 4651                                                [SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS, SEX OFFENDER: FAIL REG NEW ADD]
# 4652                                                              [SEX OFFENDER - PROHIBITED ZONE, SEX OFFENDER: PROHIBITED ZONE]
# 5003                                                           [OTHER ARSON / EXPLOSIVE INCIDENT, OTHER ARSON/EXPLOSIVE INCIDENT]
# 5004                                                                       [ATTEMPT CRIMINAL SEXUAL ABUSE, ATT CRIM SEXUAL ABUSE]
# 031A                                                                                            [ARMED - HANDGUN, ARMED: HANDGUN]
# 031B                                                                                [ARMED - OTHER FIREARM, ARMED: OTHER FIREARM]
# 033A                                                                            [ATTEMPT ARMED - HANDGUN, ATTEMPT: ARMED-HANDGUN]
# 033B                                                                [ATTEMPT ARMED - OTHER FIREARM, ATTEMPT: ARMED-OTHER FIREARM]
# 041A                                                                                  [AGGRAVATED - HANDGUN, AGGRAVATED: HANDGUN]
# 041B                                                                      [AGGRAVATED - OTHER FIREARM, AGGRAVATED: OTHER FIREARM]
# 051A                                                                                  [AGGRAVATED - HANDGUN, AGGRAVATED: HANDGUN]
# 051B                                                                      [AGGRAVATED - OTHER FIREARM, AGGRAVATED: OTHER FIREARM]
# 141A                                                                               [UNLAWFUL USE - HANDGUN, UNLAWFUL USE HANDGUN]
# 141B                                                                   [UNLAWFUL USE - OTHER FIREARM, UNLAWFUL USE OTHER FIREARM]
# 141C                                                      [UNLAWFUL USE - OTHER DANGEROUS WEAPON, UNLAWFUL USE OTHER DANG WEAPON]
# 142A                                                                             [UNLAWFUL SALE - HANDGUN, UNLAWFUL SALE HANDGUN]
# 143A                                                                    [UNLAWFUL POSSESSION - HANDGUN, UNLAWFUL POSS OF HANDGUN]
# 143B                                                           [UNLAWFUL POSSESSION - OTHER FIREARM, UNLAWFUL POSS OTHER FIREARM]
# 143C                                                                 [UNLAWFUL POSSESSION - AMMUNITION, UNLAWFUL POSS AMMUNITION]
# 502P                                                                     [FALSE / STOLEN / ALTERED TRP, FALSE/STOLEN/ALTERED TRP]
# Name: Description, dtype: object

# %%
# df['Description'] = df['Description'].replace({
#     'AGGRAVATED: HANDGUN' : 'AGGRAVATED - HANDGUN',
#     'AGGRAVATED: OTHER FIREARM' : 'AGGRAVATED - OTHER FIREARM',
#     'AGGRAVATED: KNIFE/CUT INSTR' : 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#     'AGGRAVATED: OTHER DANG WEAPON' : 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#     'AGGRAVATED - OTHER DANGEROUS WEAPON' : 'AGGRAVATED - OTHER',
#     'ATTEMPT AGG: HANDGUN' : 'ATTEMPT AGGRAVATED - HANDGUN',
#     'ATTEMPT AGG: KNIFE/CUT INSTR' : 'ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#     'ATTEMPT AGG: OTHER DANG WEAPON' : 'ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON',
#     'ATTEMPT AGG: OTHER' : 'ATTEMPT AGGRAVATED - OTHER',
#     'ARMED:KNIFE/CUTTING INSTRUMENT' : 'ARMED - KNIFE / CUTTING INSTRUMENT',
#     'ARMED: OTHER DANGEROUS WEAPON' : 'ARMED - OTHER DANGEROUS WEAPON',
#     'STRONGARM - NO WEAPON' : 'STRONG ARM - NO WEAPON',
#     'ATTEMPT: AGGRAVATED' : 'ATTEMPT AGGRAVATED',
#     'ATTEMPT: ARMED-KNIFE/CUT INSTR' : 'ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT',
#     'ATTEMPT: ARMED-OTHER DANG WEAP' : 'ATTEMPT ARMED - OTHER DANGEROUS WEAPON',
#     'ATTEMPT: STRONGARM-NO WEAPON' : 'ATTEMPT STRONG ARM - NO WEAPON',
#     'AGGRAVATED:KNIFE/CUTTING INSTR' : 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#     'AGGRAVATED: OTHER DANG WEAPON' : 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#     'AGG: HANDS/FIST/FEET NO/MINOR INJURY' : 'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY',
#     'AGGRAVATED PO: HANDGUN' : 'AGGRAVATED POLICE OFFICER - HANDGUN',
#     'AGGRAVATED PO: KNIFE/CUT INSTR' : 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
#     'AGGRAVATED PO: OTHER DANG WEAP' : 'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
#     'AGG PO HANDS NO/MIN INJURY' : 'AGGRAVATED PO - HANDS, FISTS, FEET, NO / MINOR INJURY',
#     'AGG PRO.EMP:KNIFE/CUTTING INST' : 'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT',
#     'AGG PRO.EMP: OTHER DANG WEAPON' : 'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON',
#     'PRO EMP HANDS NO/MIN INJURY' : 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#     'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST' : 'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT',
#     'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON' : 'AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON',
#     'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY' : 'AGGRAVATED DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
#     'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY' : 'AGGRAVATED DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
#     'AGGRAVATED:KNIFE/CUTTING INSTR' : 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#     'AGGRAVATED: OTHER DANG WEAPON' : 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#     'PRO EMP HANDS NO/MIN INJURY' : 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#     'AGGRAVATED PO: HANDGUN' : 'AGGRAVATED POLICE OFFICER - HANDGUN',
#     'AGGRAVATED PO: OTHER FIREARM' : 'AGGRAVATED POLICE OFFICER - OTHER FIREARM',
#     'AGGRAVATED PO:KNIFE/CUT INSTR' : 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
#     'AGGRAVATED PO: OTHER DANG WEAP' : 'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
#     'AGG PO HANDS NO/MIN INJURY' : 'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY',
#     'OVER $500' : 'THEFT AMOUNT OVER $300',
#     'OVER $300' : 'THEFT AMOUNT OVER $300',
#     '$500 AND UNDER' : 'THEFT AMOUNT UNDER $500',
#     '$300 AND UNDER' : 'THEFT AMOUNT UNDER $500',
#     'FINANCIAL ID THEFT: OVER $300' : 'FINANCIAL IDENTITY THEFT - OVER $300',
#     'FINANCIAL IDENTITY THEFT: OVER $300' : 'FINANCIAL IDENTITY THEFT - OVER $300',
#     'FINANCIAL ID THEFT:$300 &UNDER' : 'FINANCIAL IDENTITY THEFT - $300 & UNDER',
#     'FINANCIAL IDENTITY THEFT: $300 & UNDER' : 'FINANCIAL IDENTITY THEFT - $300 & UNDER',
#     'CYCLE, SCOOTER, BIKE W-VIN' : 'CYCLE, SCOOTER, BIKE WITH VIN',
#     'THEFT/RECOVERY: AUTOMOBILE' : 'THEFT / RECOVERY - AUTOMOBILE',
#     'THEFT/RECOVERY: TRUCK,BUS,MHOME' : 'THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME',
#     'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN' : 'THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN',
#     'POS: EXPLOSIVE/INCENDIARY DEV' : 'POSSESSION - EXPLOSIVE / INCENDIARY DEVICE',
#     'FINAN EXPLOIT-ELDERLY/DISABLED' : 'FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON',
#     'STOLEN PROP: BUY/RECEIVE/POS.' : 'STOLEN PROPERTY - BUY / RECEIVE / POSSESS',
#     'THEFT BY LESSEE,MOTOR VEH' : 'THEFT BY LESSEE, MOTOR VEHICLE',
#     'THEFT OF LABOR/SERVICES' : 'THEFT OF LABOR / SERVICES',
#     'THEFT OF LOST/MISLAID PROP' : 'THEFT OF LOST / MISLAID PROPERTY',
#     'TO STATE SUP PROP' : 'TO STATE SUPPORTED PROPERTY',
#     'DEFACE IDENT MARKS OF FIREARM' : 'DEFACE IDENTIFICATION MARKS OF FIREARM',
#     'POSS FIREARM/AMMO:NO FOID CARD' : 'POSSESS FIREARM / AMMUNITION - NO FOID CARD',
#     'SOLICIT FOR BUSINESS' : 'SOLICITING FOR BUSINESS',
#     'SALE/DIST OBSCENE MAT TO MINOR' : 'SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR',
#     'AGG CRIMINAL SEXUAL ABUSE' : 'AGGRAVATED CRIMINAL SEXUAL ABUSE',
#     'INDECENT SOLICITATION/CHILD' : 'INDECENT SOLICITATION OF A CHILD',
#     'INDECENT SOLICITATION/ADULT' : 'INDECENT SOLICITATION OF AN ADULT',
#     'SEX RELATION IN FAMILY' : 'SEXUAL RELATIONS IN FAMILY',
#     'NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES' : 'NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES',
#     'ATT AGG CRIMINAL SEXUAL ABUSE' : 'ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE',
#     'ENDANGERING LIFE/HEALTH CHILD' : 'ENDANGERING LIFE / HEALTH OF CHILD',
#     'CONTRIBUTE DELINQUENCY OF A CHILD' : 'CONTRIBUTE TO THE DELINQUENCY OF CHILD',
#     'CRIM SEX ABUSE BY FAM MEMBER' : 'CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
#     'AGG CRIM SEX ABUSE FAM MEMBER' : 'AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
#     'SEX ASSLT OF CHILD BY FAM MBR' : 'SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
#     'AGG SEX ASSLT OF CHILD FAM MBR' : 'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
#     'CHILD ABDUCTION/STRANGER' : 'CHILD ABDUCTION / STRANGER',
#     'POSS: CANNABIS 30GMS OR LESS' : 'POSSESS - CANNABIS 30 GRAMS OR LESS',
#     'POSS: CANNABIS MORE THAN 30GMS' : 'POSSESS - CANNABIS MORE THAN 30 GRAMS',
#     'MANU/DEL:CANNABIS 10GM OR LESS' : 'MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS',
#     'MANU/DEL:CANNABIS OVER 10 GMS' : 'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS',
#     'DELIVER CANNABIS TO PERSON <18' : 'DELIVER CANNABIS TO PERSON UNDER 18',
#     'MANU/DELIVER:AMPHETAMINES' : 'MANUFACTURE / DELIVER - AMPHETAMINES',
#     'MANU/DELIVER:BARBITUATES' : 'MANUFACTURE / DELIVER - BARBITURATES',
#     'MANU/DELIVER:COCAINE' : 'MANUFACTURE / DELIVER - COCAINE',
#     'MANU/DELIVER: HEROIN(BRN/TAN)' : 'MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR)',
#     'MANU/DELIVER: HEROIN (WHITE)' : 'MANUFACTURE / DELIVER -  HEROIN (WHITE)',
#     'MANU/DELIVER: HALLUCINOGEN' : 'MANUFACTURE / DELIVER - HALLUCINOGEN',
#     'MANU/DELIVER:PCP' : 'MANUFACTURE / DELIVER - PCP',
#     'MANU/DELIVER:CRACK' : 'MANUFACTURE / DELIVER - CRACK',
#     'MANU/DELIVER:SYNTHETIC DRUGS' : 'MANUFACTURE / DELIVER - SYNTHETIC DRUGS',
#     'POSS: AMPHETAMINES' : 'POSSESS - AMPHETAMINES',
#     'POSS: BARBITUATES' : 'POSSESS - BARBITURATES',
#     'POSS: COCAINE' : 'POSSESS - COCAINE',
#     'POSS: HEROIN(BRN/TAN)' : 'POSSESS - HEROIN (TAN / BROWN TAR)',
#     'POSS: HEROIN(WHITE)' : 'POSSESS - HEROIN (WHITE)',
#     'POSS: HALLUCINOGENS' : 'POSSESS - HALLUCINOGENS',
#     'POSS: PCP' : 'POSSESS - PCP',
#     'POSS: CRACK' : 'POSSESS - CRACK',
#     'POSS: SYNTHETIC DRUGS' : 'POSSESS - SYNTHETIC DRUGS',
#     'POSS: HEROIN(BLACK TAR)' : 'POSSESS - HEROIN (BLACK TAR)',
#     'MANU/DELIVER:LOOK-ALIKE DRUG' : 'MANUFACTURE / DELIVER - LOOK-ALIKE DRUG',
#     'POSS: LOOK-ALIKE DRUGS' : 'POSSESS - LOOK-ALIKE DRUGS',
#     'ALTER/FORGE PRESCRIPTION' : 'ALTER / FORGE PRESCRIPTION',
#     'SOLICIT NARCOTICS ON PUBLICWAY' : 'SOLICIT NARCOTICS ON PUBLIC WAY',
#     'SELL/GIVE/DEL LIQUOR TO MINOR' : 'SELL / GIVE / DELIVER LIQUOR TO MINOR',
#     'UNLAWFUL USE/SALE AIR RIFLE' : 'UNLAWFUL USE / SALE OF AIR RIFLE',
#     'RESIST/OBSTRUCT/DISARM OFFICER' : '[RESIST / OBSTRUCT / DISARM OFFICER',
#     'UNLAWFUL INTERFERE/VISITATION' : 'UNLAWFUL VISITATION INTERFERENCE',
#     'VIO BAIL BOND: DOM VIOLENCE' : 'VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE',
#     'SEX OFFENDER: FAIL TO REGISTER' : 'SEX OFFENDER - FAIL TO REGISTER',
#     'SEX OFFENDER: FAIL REG NEW ADD' : 'SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS',
#     'SEX OFFENDER: PROHIBITED ZONE' : 'SEX OFFENDER - PROHIBITED ZONE',
#     'OTHER ARSON/EXPLOSIVE INCIDENT' : 'OTHER ARSON / EXPLOSIVE INCIDENT',
#     'ATT CRIM SEXUAL ABUSE' : 'ATTEMPT CRIMINAL SEXUAL ABUSE',
#     'ARMED: HANDGUN' : 'ARMED - HANDGUN',
#     'ARMED: OTHER FIREARM' : 'ARMED - OTHER FIREARM',
#     'ATTEMPT: ARMED-HANDGUN' : 'ATTEMPT ARMED - HANDGUN',
#     'ATTEMPT: ARMED-OTHER FIREARM' : 'ATTEMPT ARMED - OTHER FIREARM',
#     'AGGRAVATED: HANDGUN' : 'AGGRAVATED - HANDGUN',
#     'AGGRAVATED: OTHER FIREARM' : 'AGGRAVATED - OTHER FIREARM',
#     'AGGRAVATED: HANDGUN' : 'AGGRAVATED - HANDGUN',
#     'AGGRAVATED: OTHER FIREARM' : 'AGGRAVATED - OTHER FIREARM',
#     'UNLAWFUL USE HANDGUN' : 'UNLAWFUL USE - HANDGUN',
#     'UNLAWFUL USE OTHER FIREARM' : 'UNLAWFUL USE - OTHER FIREARM',
#     'UNLAWFUL USE OTHER DANG WEAPON' : 'UNLAWFUL USE - OTHER DANGEROUS WEAPON',
#     'UNLAWFUL SALE HANDGUN' : 'UNLAWFUL SALE - HANDGUN',
#     'UNLAWFUL POSS OF HANDGUN' : 'UNLAWFUL POSSESSION - HANDGUN',
#     'UNLAWFUL POSS OTHER FIREARM' : 'UNLAWFUL POSSESSION - OTHER FIREARM',
#     'UNLAWFUL POSS AMMUNITION' : 'UNLAWFUL POSSESSION - AMMUNITION',
#     'FALSE/STOLEN/ALTERED TRP' : 'FALSE / STOLEN / ALTERED TRP'
#     })

# %%
# Captialize the values in the column
def captialize_values(dataframe, column_name):
    try:
        dataframe[column_name] = dataframe[column_name].apply(lambda x: x.upper() if x!=x.upper() else x)
        print(f'successfully captialized the {column_name} column')
    except Exception as e:
        print(f'Error occured when captialize the values in {column_name} column :',e)

# %%
captialize_values(df, 'Block')  # captialize the values in the 'Block' column

# Handled the 'Primary Type' column where values have the same meaning but with variations and different spelling
df['Primary Type'] = df['Primary Type'].replace({'CRIM SEXUAL ASSAULT': 'CRIMINAL SEXUAL ASSAULT','OTHER NARCOTIC VIOLATION': 'NARCOTICS'})  

# Handled the 'Description' column where values have the same meaning but with variations and different spelling
df['Description'] = df['Description'].replace({
    'AGGRAVATED: HANDGUN' : 'AGGRAVATED - HANDGUN',
    'AGGRAVATED: OTHER FIREARM' : 'AGGRAVATED - OTHER FIREARM',
    'AGGRAVATED: KNIFE/CUT INSTR' : 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
    'AGGRAVATED: OTHER DANG WEAPON' : 'AGGRAVATED - OTHER DANGEROUS WEAPON',
    'AGGRAVATED - OTHER DANGEROUS WEAPON' : 'AGGRAVATED - OTHER',
    'ATTEMPT AGG: HANDGUN' : 'ATTEMPT AGGRAVATED - HANDGUN',
    'ATTEMPT AGG: KNIFE/CUT INSTR' : 'ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
    'ATTEMPT AGG: OTHER DANG WEAPON' : 'ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON',
    'ATTEMPT AGG: OTHER' : 'ATTEMPT AGGRAVATED - OTHER',
    'ARMED:KNIFE/CUTTING INSTRUMENT' : 'ARMED - KNIFE / CUTTING INSTRUMENT',
    'ARMED: OTHER DANGEROUS WEAPON' : 'ARMED - OTHER DANGEROUS WEAPON',
    'STRONGARM - NO WEAPON' : 'STRONG ARM - NO WEAPON',
    'ATTEMPT: AGGRAVATED' : 'ATTEMPT AGGRAVATED',
    'ATTEMPT: ARMED-KNIFE/CUT INSTR' : 'ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT',
    'ATTEMPT: ARMED-OTHER DANG WEAP' : 'ATTEMPT ARMED - OTHER DANGEROUS WEAPON',
    'ATTEMPT: STRONGARM-NO WEAPON' : 'ATTEMPT STRONG ARM - NO WEAPON',
    'AGGRAVATED:KNIFE/CUTTING INSTR' : 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
    'AGGRAVATED: OTHER DANG WEAPON' : 'AGGRAVATED - OTHER DANGEROUS WEAPON',
    'AGG: HANDS/FIST/FEET NO/MINOR INJURY' : 'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY',
    'AGGRAVATED PO: HANDGUN' : 'AGGRAVATED POLICE OFFICER - HANDGUN',
    'AGGRAVATED PO: KNIFE/CUT INSTR' : 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
    'AGGRAVATED PO: OTHER DANG WEAP' : 'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
    'AGG PO HANDS NO/MIN INJURY' : 'AGGRAVATED PO - HANDS, FISTS, FEET, NO / MINOR INJURY',
    'AGG PRO.EMP:KNIFE/CUTTING INST' : 'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT',
    'AGG PRO.EMP: OTHER DANG WEAPON' : 'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON',
    'PRO EMP HANDS NO/MIN INJURY' : 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
    'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST' : 'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT',
    'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON' : 'AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON',
    'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY' : 'AGGRAVATED DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
    'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY' : 'AGGRAVATED DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
    'AGGRAVATED:KNIFE/CUTTING INSTR' : 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
    'AGGRAVATED: OTHER DANG WEAPON' : 'AGGRAVATED - OTHER DANGEROUS WEAPON',
    'PRO EMP HANDS NO/MIN INJURY' : 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
    'AGGRAVATED PO: HANDGUN' : 'AGGRAVATED POLICE OFFICER - HANDGUN',
    'AGGRAVATED PO: OTHER FIREARM' : 'AGGRAVATED POLICE OFFICER - OTHER FIREARM',
    'AGGRAVATED PO:KNIFE/CUT INSTR' : 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
    'AGGRAVATED PO: OTHER DANG WEAP' : 'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
    'AGG PO HANDS NO/MIN INJURY' : 'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY',
    'OVER $500' : 'THEFT AMOUNT OVER $300',
    'OVER $300' : 'THEFT AMOUNT OVER $300',
    '$500 AND UNDER' : 'THEFT AMOUNT UNDER $500',
    '$300 AND UNDER' : 'THEFT AMOUNT UNDER $500',
    'FINANCIAL ID THEFT: OVER $300' : 'FINANCIAL IDENTITY THEFT - OVER $300',
    'FINANCIAL IDENTITY THEFT: OVER $300' : 'FINANCIAL IDENTITY THEFT - OVER $300',
    'FINANCIAL ID THEFT:$300 &UNDER' : 'FINANCIAL IDENTITY THEFT - $300 & UNDER',
    'FINANCIAL IDENTITY THEFT: $300 & UNDER' : 'FINANCIAL IDENTITY THEFT - $300 & UNDER',
    'CYCLE, SCOOTER, BIKE W-VIN' : 'CYCLE, SCOOTER, BIKE WITH VIN',
    'THEFT/RECOVERY: AUTOMOBILE' : 'THEFT / RECOVERY - AUTOMOBILE',
    'THEFT/RECOVERY: TRUCK,BUS,MHOME' : 'THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME',
    'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN' : 'THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN',
    'POS: EXPLOSIVE/INCENDIARY DEV' : 'POSSESSION - EXPLOSIVE / INCENDIARY DEVICE',
    'FINAN EXPLOIT-ELDERLY/DISABLED' : 'FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON',
    'STOLEN PROP: BUY/RECEIVE/POS.' : 'STOLEN PROPERTY - BUY / RECEIVE / POSSESS',
    'THEFT BY LESSEE,MOTOR VEH' : 'THEFT BY LESSEE, MOTOR VEHICLE',
    'THEFT OF LABOR/SERVICES' : 'THEFT OF LABOR / SERVICES',
    'THEFT OF LOST/MISLAID PROP' : 'THEFT OF LOST / MISLAID PROPERTY',
    'TO STATE SUP PROP' : 'TO STATE SUPPORTED PROPERTY',
    'DEFACE IDENT MARKS OF FIREARM' : 'DEFACE IDENTIFICATION MARKS OF FIREARM',
    'POSS FIREARM/AMMO:NO FOID CARD' : 'POSSESS FIREARM / AMMUNITION - NO FOID CARD',
    'SOLICIT FOR BUSINESS' : 'SOLICITING FOR BUSINESS',
    'SALE/DIST OBSCENE MAT TO MINOR' : 'SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR',
    'AGG CRIMINAL SEXUAL ABUSE' : 'AGGRAVATED CRIMINAL SEXUAL ABUSE',
    'INDECENT SOLICITATION/CHILD' : 'INDECENT SOLICITATION OF A CHILD',
    'INDECENT SOLICITATION/ADULT' : 'INDECENT SOLICITATION OF AN ADULT',
    'SEX RELATION IN FAMILY' : 'SEXUAL RELATIONS IN FAMILY',
    'NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES' : 'NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES',
    'ATT AGG CRIMINAL SEXUAL ABUSE' : 'ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE',
    'ENDANGERING LIFE/HEALTH CHILD' : 'ENDANGERING LIFE / HEALTH OF CHILD',
    'CONTRIBUTE DELINQUENCY OF A CHILD' : 'CONTRIBUTE TO THE DELINQUENCY OF CHILD',
    'CRIM SEX ABUSE BY FAM MEMBER' : 'CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
    'AGG CRIM SEX ABUSE FAM MEMBER' : 'AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
    'SEX ASSLT OF CHILD BY FAM MBR' : 'SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
    'AGG SEX ASSLT OF CHILD FAM MBR' : 'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
    'CHILD ABDUCTION/STRANGER' : 'CHILD ABDUCTION / STRANGER',
    'POSS: CANNABIS 30GMS OR LESS' : 'POSSESS - CANNABIS 30 GRAMS OR LESS',
    'POSS: CANNABIS MORE THAN 30GMS' : 'POSSESS - CANNABIS MORE THAN 30 GRAMS',
    'MANU/DEL:CANNABIS 10GM OR LESS' : 'MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS',
    'MANU/DEL:CANNABIS OVER 10 GMS' : 'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS',
    'DELIVER CANNABIS TO PERSON <18' : 'DELIVER CANNABIS TO PERSON UNDER 18',
    'MANU/DELIVER:AMPHETAMINES' : 'MANUFACTURE / DELIVER - AMPHETAMINES',
    'MANU/DELIVER:BARBITUATES' : 'MANUFACTURE / DELIVER - BARBITURATES',
    'MANU/DELIVER:COCAINE' : 'MANUFACTURE / DELIVER - COCAINE',
    'MANU/DELIVER: HEROIN(BRN/TAN)' : 'MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR)',
    'MANU/DELIVER: HEROIN (WHITE)' : 'MANUFACTURE / DELIVER -  HEROIN (WHITE)',
    'MANU/DELIVER: HALLUCINOGEN' : 'MANUFACTURE / DELIVER - HALLUCINOGEN',
    'MANU/DELIVER:PCP' : 'MANUFACTURE / DELIVER - PCP',
    'MANU/DELIVER:CRACK' : 'MANUFACTURE / DELIVER - CRACK',
    'MANU/DELIVER:SYNTHETIC DRUGS' : 'MANUFACTURE / DELIVER - SYNTHETIC DRUGS',
    'POSS: AMPHETAMINES' : 'POSSESS - AMPHETAMINES',
    'POSS: BARBITUATES' : 'POSSESS - BARBITURATES',
    'POSS: COCAINE' : 'POSSESS - COCAINE',
    'POSS: HEROIN(BRN/TAN)' : 'POSSESS - HEROIN (TAN / BROWN TAR)',
    'POSS: HEROIN(WHITE)' : 'POSSESS - HEROIN (WHITE)',
    'POSS: HALLUCINOGENS' : 'POSSESS - HALLUCINOGENS',
    'POSS: PCP' : 'POSSESS - PCP',
    'POSS: CRACK' : 'POSSESS - CRACK',
    'POSS: SYNTHETIC DRUGS' : 'POSSESS - SYNTHETIC DRUGS',
    'POSS: HEROIN(BLACK TAR)' : 'POSSESS - HEROIN (BLACK TAR)',
    'MANU/DELIVER:LOOK-ALIKE DRUG' : 'MANUFACTURE / DELIVER - LOOK-ALIKE DRUG',
    'POSS: LOOK-ALIKE DRUGS' : 'POSSESS - LOOK-ALIKE DRUGS',
    'ALTER/FORGE PRESCRIPTION' : 'ALTER / FORGE PRESCRIPTION',
    'SOLICIT NARCOTICS ON PUBLICWAY' : 'SOLICIT NARCOTICS ON PUBLIC WAY',
    'SELL/GIVE/DEL LIQUOR TO MINOR' : 'SELL / GIVE / DELIVER LIQUOR TO MINOR',
    'UNLAWFUL USE/SALE AIR RIFLE' : 'UNLAWFUL USE / SALE OF AIR RIFLE',
    'RESIST/OBSTRUCT/DISARM OFFICER' : '[RESIST / OBSTRUCT / DISARM OFFICER',
    'UNLAWFUL INTERFERE/VISITATION' : 'UNLAWFUL VISITATION INTERFERENCE',
    'VIO BAIL BOND: DOM VIOLENCE' : 'VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE',
    'SEX OFFENDER: FAIL TO REGISTER' : 'SEX OFFENDER - FAIL TO REGISTER',
    'SEX OFFENDER: FAIL REG NEW ADD' : 'SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS',
    'SEX OFFENDER: PROHIBITED ZONE' : 'SEX OFFENDER - PROHIBITED ZONE',
    'OTHER ARSON/EXPLOSIVE INCIDENT' : 'OTHER ARSON / EXPLOSIVE INCIDENT',
    'ATT CRIM SEXUAL ABUSE' : 'ATTEMPT CRIMINAL SEXUAL ABUSE',
    'ARMED: HANDGUN' : 'ARMED - HANDGUN',
    'ARMED: OTHER FIREARM' : 'ARMED - OTHER FIREARM',
    'ATTEMPT: ARMED-HANDGUN' : 'ATTEMPT ARMED - HANDGUN',
    'ATTEMPT: ARMED-OTHER FIREARM' : 'ATTEMPT ARMED - OTHER FIREARM',
    'AGGRAVATED: HANDGUN' : 'AGGRAVATED - HANDGUN',
    'AGGRAVATED: OTHER FIREARM' : 'AGGRAVATED - OTHER FIREARM',
    'AGGRAVATED: HANDGUN' : 'AGGRAVATED - HANDGUN',
    'AGGRAVATED: OTHER FIREARM' : 'AGGRAVATED - OTHER FIREARM',
    'UNLAWFUL USE HANDGUN' : 'UNLAWFUL USE - HANDGUN',
    'UNLAWFUL USE OTHER FIREARM' : 'UNLAWFUL USE - OTHER FIREARM',
    'UNLAWFUL USE OTHER DANG WEAPON' : 'UNLAWFUL USE - OTHER DANGEROUS WEAPON',
    'UNLAWFUL SALE HANDGUN' : 'UNLAWFUL SALE - HANDGUN',
    'UNLAWFUL POSS OF HANDGUN' : 'UNLAWFUL POSSESSION - HANDGUN',
    'UNLAWFUL POSS OTHER FIREARM' : 'UNLAWFUL POSSESSION - OTHER FIREARM',
    'UNLAWFUL POSS AMMUNITION' : 'UNLAWFUL POSSESSION - AMMUNITION',
    'FALSE/STOLEN/ALTERED TRP' : 'FALSE / STOLEN / ALTERED TRP',
    'AGGRAVATED - OTHER' : 'AGGRAVATED - OTHER DANGEROUS WEAPON',
    'AGGRAVATED: OTHER' : 'AGGRAVATED - OTHER',
    'AGGRAVATED - OTHER' : 'AGGRAVATED - OTHER DANGEROUS WEAPON',
    'AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY' : 'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY',
    'ATT: AUTOMOBILE' : 'ATTEMPT - AUTOMOBILE',
    'ATT: TRUCK, BUS, MOTOR HOME' : 'ATTEMPT - TRUCK, BUS, MOTOR HOME',
    'ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN' : 'ATTEMPT - CYCLE, SCOOTER, BIKE WITH VIN',
    'STOLEN PROPERTY BUY / RECEIVE / POSSESS' : 'STOLEN PROPERTY - BUY / RECEIVE / POSSESS',
    'THEFT BY LESSEE,NON-VEH' : 'THEFT BY LESSEE, NON-MOTOR VEHICLE',
    'RESIST / OBSTRUCT / DISARM OFFICER' : 'RESIST / OBSTRUCT / DISARM OFFICER',
    'AGGRAVATED - OTHER': 'AGGRAVATED - OTHER DANGEROUS WEAPON',
    'AGGRAVATED - OTHER DANGEROUS WEAPON': 'AGGRAVATED - OTHER DANGEROUS WEAPON',
    '[RESIST / OBSTRUCT / DISARM OFFICER' : 'RESIST / OBSTRUCT / DISARM OFFICER',
    '[RESIST / OBSTRUCT / DISARM OFFICER]' : 'RESIST / OBSTRUCT / DISARM OFFICER'
})

# Handled the 'Location Description' column where values have the same meaning but with variations and different spelling
df['Location Description'] = df['Location Description'].replace({
    'RESIDENCE-GARAGE' : 'RESIDENCE - GARAGE',
    'RESIDENCE PORCH/HALLWAY' : 'RESIDENCE - PORCH / HALLWAY',
    'RESIDENTIAL YARD (FRONT/BACK)' : 'RESIDENCE - YARD (FRONT / BACK)',
    'VACANT LOT/LAND' : 'VACANT LOT / LAND',
    'VACANT LOT' : 'VACANT LOT / LAND',
    'HOSPITAL BUILDING/GROUNDS' : 'HOSPITAL BUILDING / GROUNDS',
    'HOTEL/MOTEL' : 'HOTEL / MOTEL',
    'SCHOOL, PUBLIC, BUILDING' : 'SCHOOL - PUBLIC BUILDING',
    'SCHOOL, PUBLIC, GROUNDS' : 'SCHOOL - PUBLIC GROUNDS',
    'SCHOOL, PRIVATE, GROUNDS' : 'SCHOOL - PRIVATE GROUNDS',
    'SCHOOL, PRIVATE, BUILDING' : 'SCHOOL - PRIVATE BUILDING',
    'CHA HALLWAY/STAIRWELL/ELEVATOR' : 'CHA HALLWAY / STAIRWELL / ELEVATOR',
    'CHA PARKING LOT/GROUNDS' : 'CHA PARKING LOT / GROUNDS',
    'GOVERNMENT BUILDING/PROPERTY' : 'GOVERNMENT BUILDING / PROPERTY',
    'CHURCH/SYNAGOGUE/PLACE OF WORSHIP' : 'CHURCH / SYNAGOGUE / PLACE OF WORSHIP',
    'MOVIE HOUSE/THEATER' : 'MOVIE HOUSE / THEATER',
    'FACTORY/MANUFACTURING BUILDING' : 'FACTORY / MANUFACTURING BUILDING',
    'LAKEFRONT/WATERFRONT/RIVERBANK' : 'LAKEFRONT / WATERFRONT / RIVERBANK',
    'NURSING HOME/RETIREMENT HOME' : 'NURSING / RETIREMENT HOME',
    'PARKING LOT/GARAGE(NON.RESID.)' : 'PARKING LOT / GARAGE (NON RESIDENTIAL)',
    'POLICE FACILITY/VEH PARKING LOT' : 'POLICE FACILITY / VEHICLE PARKING LOT',
    'TAVERN/LIQUOR STORE' : 'TAVERN / LIQUOR STORE',
    'SPORTS ARENA/STADIUM' : 'SPORTS ARENA / STADIUM',
    'MEDICAL/DENTAL OFFICE' : 'MEDICAL / DENTAL OFFICE'
})
# Out:
# successfully captialized the Block column

# %%
# df['Location Description'] = df['Location Description'].replace({
#     'RESIDENCE-GARAGE' : 'RESIDENCE - GARAGE',
#     'RESIDENCE PORCH/HALLWAY' : 'RESIDENCE - PORCH / HALLWAY',
#     'RESIDENTIAL YARD (FRONT/BACK)' : 'RESIDENCE - YARD (FRONT / BACK)',
#     'VACANT LOT/LAND' : 'VACANT LOT / LAND',
#     'VACANT LOT' : 'VACANT LOT / LAND',
#     'HOSPITAL BUILDING/GROUNDS' : 'HOSPITAL BUILDING / GROUNDS',
#     'HOTEL/MOTEL' : 'HOTEL / MOTEL',
#     'SCHOOL, PUBLIC, BUILDING' : 'SCHOOL - PUBLIC BUILDING',
#     'SCHOOL, PUBLIC, GROUNDS' : 'SCHOOL - PUBLIC GROUNDS',
#     'SCHOOL, PRIVATE, GROUNDS' : 'SCHOOL - PRIVATE GROUNDS',
#     'SCHOOL, PRIVATE, BUILDING' : 'SCHOOL - PRIVATE BUILDING',
#     'CHA HALLWAY/STAIRWELL/ELEVATOR' : 'CHA HALLWAY / STAIRWELL / ELEVATOR',
#     'CHA PARKING LOT/GROUNDS' : 'CHA PARKING LOT / GROUNDS',
#     'GOVERNMENT BUILDING/PROPERTY' : 'GOVERNMENT BUILDING / PROPERTY',
#     'CHURCH/SYNAGOGUE/PLACE OF WORSHIP' : 'CHURCH / SYNAGOGUE / PLACE OF WORSHIP',
#     'MOVIE HOUSE/THEATER' : 'MOVIE HOUSE / THEATER',
#     'FACTORY/MANUFACTURING BUILDING' : 'FACTORY / MANUFACTURING BUILDING',
#     'LAKEFRONT/WATERFRONT/RIVERBANK' : 'LAKEFRONT / WATERFRONT / RIVERBANK',
#     'NURSING HOME/RETIREMENT HOME' : 'NURSING / RETIREMENT HOME',
#     'PARKING LOT/GARAGE(NON.RESID.)' : 'PARKING LOT / GARAGE (NON RESIDENTIAL)',
#     'POLICE FACILITY/VEH PARKING LOT' : 'POLICE FACILITY / VEHICLE PARKING LOT',
# })

# %%
# Conclusion from Step 2 -- there is some misspelled values and value with same name with different meaning , handled it using mapping method

# %% [markdown]
# ##### Step 3 - handle null values

# %%
df.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      1673
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    336325
# Community Area          334906
# FBI Code                     0
# X Coordinate              6912
# Y Coordinate              6912
# Year                         0
# Updated On                   0
# Latitude                  6912
# Longitude                 6912
# Location                  6912
# dtype: int64

# %%
# since there is very less number of null values in 'Location Description', 'X Coordinate', 'Y Coordinate', 'Latitude', 'Longitude' columns , so dropped the column
df.dropna(subset=['Location Description', 'X Coordinate', 'Y Coordinate', 'Latitude', 'Longitude'], inplace=True)

# %%
ref = (df.groupby(['Block', 'Location Description', 'District'])[['Ward', 'Community Area']].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).reset_index()
    .rename(columns={'Ward': 'Ward_Filled', 'Community Area': 'Community_Area_Filled'}))

df = df.merge(ref, on=['Block', 'Location Description', 'District'], how='left')

df['Ward'] = df['Ward'].fillna(df['Ward_Filled'])
df['Community Area'] = df['Community Area'].fillna(df['Community_Area_Filled'])

df = df.drop(columns=['Ward_Filled', 'Community_Area_Filled'])

# %%
df.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %%
# even after handling null values in "Ward" and "Community Area" columns, there are null values present there, since handling these values by taking mean or median or mode will not be recommended , 
# so fill the null values with "-1" , this -1 indicates unknown in numerical column

df['Ward'] = df['Ward'].fillna(-1)
df['Community Area'] = df['Community Area'].fillna(-1)

# %%
# Conclusion from Step 3 - handled null values in ward and community area , and filled the remaining null values  and dropped the null values in 'Location Description', 'X Coordinate', 'Y Coordinate', 'Latitude', 'Longitude' columns, 
# the reason for dropped this values instead of handled is , these column depends on place where the crime happened , since it is a sensitive data filling this data by taking mean, mode, median or grouping with other values is not correct

# %% [markdown]
# ##### Step 4 - handle duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Conclusion from Step 4 - there is no duplicate data in the dataset

# %% [markdown]
# ##### Step 5 - Feature Engineering

# %%
df['Crime_occured_date'] = df['Date'].dt.date
df['Crime_occured_day'] = df['Date'].dt.day
df['Crime_occured_month'] = df['Date'].dt.month
df['Crime_occured_year'] = df['Date'].dt.year
df['Crime_occured_time'] = df['Date'].dt.time
df['Crime_occured_day_of_week'] = df['Date'].dt.day_name()
df['Crime_occured_is_weekend'] = df['Date'].dt.day_name().isin(['Saturday', 'Sunday'])

def categorize_time(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'
    
df['Crime_occured_time'] = df['Date'].dt.hour.apply(categorize_time)

# %%
df['Record_last_updated_date'] = df['Updated On'].dt.date
df['Record_last_updated_day'] = df['Updated On'].dt.day
df['Record_last_updated_month'] = df['Updated On'].dt.month
df['Record_last_updated_year'] = df['Updated On'].dt.year
df['Record_last_updated_time'] = df['Updated On'].dt.time
